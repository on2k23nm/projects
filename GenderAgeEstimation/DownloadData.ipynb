# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("abhikjha/imdb-wiki-faces-dataset")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (0.4.0).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/abhikjha/imdb-wiki-faces-dataset?dataset_version_number=2...
# 100%|██████████| 5.92G/5.92G [05:31<00:00, 19.2MB/s]
# Extracting files...
# Path to dataset files: /home/onkar/.cache/kagglehub/datasets/abhikjha/imdb-wiki-faces-dataset/versions/2
